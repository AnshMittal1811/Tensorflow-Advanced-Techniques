# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 2s 3ms/sample - loss: 239.8359 - y1_output_loss: 112.8115 - y2_output_loss: 125.0336 - y1_output_root_mean_squared_error: 10.6650 - y2_output_root_mean_squared_error: 11.2291 - val_loss: 55.6339 - val_y1_output_loss: 16.9257 - val_y2_output_loss: 38.4410 - val_y1_output_root_mean_squared_error: 4.0613 - val_y2_output_root_mean_squared_error: 6.2562
# Epoch 2/500
# 614/614 [==============================] - 0s 480us/sample - loss: 34.1875 - y1_output_loss: 12.2139 - y2_output_loss: 22.0026 - y1_output_root_mean_squared_error: 3.4881 - y2_output_root_mean_squared_error: 4.6926 - val_loss: 27.7711 - val_y1_output_loss: 13.3699 - val_y2_output_loss: 16.1483 - val_y1_output_root_mean_squared_error: 3.4977 - val_y2_output_root_mean_squared_error: 3.9417
# Epoch 3/500
# 614/614 [==============================] - 0s 474us/sample - loss: 34.8822 - y1_output_loss: 11.6827 - y2_output_loss: 23.0044 - y1_output_root_mean_squared_error: 3.4221 - y2_output_root_mean_squared_error: 4.8137 - val_loss: 22.5257 - val_y1_output_loss: 10.3810 - val_y2_output_loss: 12.3282 - val_y1_output_root_mean_squared_error: 3.1586 - val_y2_output_root_mean_squared_error: 3.5424
# Epoch 4/500
# 614/614 [==============================] - 0s 368us/sample - loss: 26.6671 - y1_output_loss: 10.1775 - y2_output_loss: 16.3944 - y1_output_root_mean_squared_error: 3.1929 - y2_output_root_mean_squared_error: 4.0587 - val_loss: 19.0827 - val_y1_output_loss: 9.3736 - val_y2_output_loss: 9.9313 - val_y1_output_root_mean_squared_error: 2.9732 - val_y2_output_root_mean_squared_error: 3.2004
# Epoch 5/500
# 614/614 [==============================] - 0s 472us/sample - loss: 28.2529 - y1_output_loss: 9.9289 - y2_output_loss: 18.1278 - y1_output_root_mean_squared_error: 3.1649 - y2_output_root_mean_squared_error: 4.2704 - val_loss: 17.5723 - val_y1_output_loss: 8.6955 - val_y2_output_loss: 8.7583 - val_y1_output_root_mean_squared_error: 2.9197 - val_y2_output_root_mean_squared_error: 3.0079
# Epoch 6/500
# 614/614 [==============================] - 0s 468us/sample - loss: 23.0453 - y1_output_loss: 8.9380 - y2_output_loss: 14.4645 - y1_output_root_mean_squared_error: 2.9848 - y2_output_root_mean_squared_error: 3.7598 - val_loss: 33.5318 - val_y1_output_loss: 12.4929 - val_y2_output_loss: 24.1243 - val_y1_output_root_mean_squared_error: 3.3110 - val_y2_output_root_mean_squared_error: 4.7507
# Epoch 7/500
# 614/614 [==============================] - 0s 476us/sample - loss: 22.4248 - y1_output_loss: 8.4057 - y2_output_loss: 14.0995 - y1_output_root_mean_squared_error: 2.9024 - y2_output_root_mean_squared_error: 3.7418 - val_loss: 21.4048 - val_y1_output_loss: 8.5443 - val_y2_output_loss: 13.2690 - val_y1_output_root_mean_squared_error: 2.8945 - val_y2_output_root_mean_squared_error: 3.6092
# Epoch 8/500
# 614/614 [==============================] - 0s 367us/sample - loss: 24.3789 - y1_output_loss: 8.9359 - y2_output_loss: 15.5594 - y1_output_root_mean_squared_error: 2.9777 - y2_output_root_mean_squared_error: 3.9386 - val_loss: 65.2822 - val_y1_output_loss: 19.5302 - val_y2_output_loss: 46.7692 - val_y1_output_root_mean_squared_error: 4.3689 - val_y2_output_root_mean_squared_error: 6.7967
# Epoch 9/500
# 614/614 [==============================] - 0s 465us/sample - loss: 22.9308 - y1_output_loss: 8.4850 - y2_output_loss: 14.4189 - y1_output_root_mean_squared_error: 2.8979 - y2_output_root_mean_squared_error: 3.8122 - val_loss: 15.7889 - val_y1_output_loss: 8.6306 - val_y2_output_loss: 8.0692 - val_y1_output_root_mean_squared_error: 2.7866 - val_y2_output_root_mean_squared_error: 2.8326
# Epoch 10/500
# 614/614 [==============================] - 0s 465us/sample - loss: 23.8568 - y1_output_loss: 8.6342 - y2_output_loss: 15.0090 - y1_output_root_mean_squared_error: 2.9515 - y2_output_root_mean_squared_error: 3.8917 - val_loss: 14.4909 - val_y1_output_loss: 7.7335 - val_y2_output_loss: 7.0909 - val_y1_output_root_mean_squared_error: 2.6910 - val_y2_output_root_mean_squared_error: 2.6924
# Epoch 11/500
# 614/614 [==============================] - 0s 367us/sample - loss: 19.9140 - y1_output_loss: 7.3662 - y2_output_loss: 12.4750 - y1_output_root_mean_squared_error: 2.7225 - y2_output_root_mean_squared_error: 3.5358 - val_loss: 15.2540 - val_y1_output_loss: 8.2909 - val_y2_output_loss: 7.6446 - val_y1_output_root_mean_squared_error: 2.7544 - val_y2_output_root_mean_squared_error: 2.7690
# Epoch 12/500
# 614/614 [==============================] - 0s 471us/sample - loss: 21.4916 - y1_output_loss: 7.7883 - y2_output_loss: 13.5871 - y1_output_root_mean_squared_error: 2.7889 - y2_output_root_mean_squared_error: 3.7032 - val_loss: 14.9203 - val_y1_output_loss: 7.2400 - val_y2_output_loss: 7.3894 - val_y1_output_root_mean_squared_error: 2.6996 - val_y2_output_root_mean_squared_error: 2.7627
# Epoch 13/500
# 614/614 [==============================] - 0s 469us/sample - loss: 22.3398 - y1_output_loss: 7.8817 - y2_output_loss: 14.2833 - y1_output_root_mean_squared_error: 2.8200 - y2_output_root_mean_squared_error: 3.7931 - val_loss: 16.9655 - val_y1_output_loss: 10.2257 - val_y2_output_loss: 9.3155 - val_y1_output_root_mean_squared_error: 2.9139 - val_y2_output_root_mean_squared_error: 2.9111
# Epoch 14/500
# 614/614 [==============================] - 0s 362us/sample - loss: 16.9141 - y1_output_loss: 6.8225 - y2_output_loss: 10.2208 - y1_output_root_mean_squared_error: 2.5921 - y2_output_root_mean_squared_error: 3.1930 - val_loss: 13.7317 - val_y1_output_loss: 7.0441 - val_y2_output_loss: 7.3271 - val_y1_output_root_mean_squared_error: 2.5491 - val_y2_output_root_mean_squared_error: 2.6896
# Epoch 15/500
# 614/614 [==============================] - 0s 473us/sample - loss: 21.1778 - y1_output_loss: 7.3737 - y2_output_loss: 13.6279 - y1_output_root_mean_squared_error: 2.7274 - y2_output_root_mean_squared_error: 3.7066 - val_loss: 12.4378 - val_y1_output_loss: 6.1480 - val_y2_output_loss: 6.3551 - val_y1_output_root_mean_squared_error: 2.4290 - val_y2_output_root_mean_squared_error: 2.5569
# Epoch 16/500
# 614/614 [==============================] - 0s 470us/sample - loss: 15.8846 - y1_output_loss: 6.0127 - y2_output_loss: 9.8951 - y1_output_root_mean_squared_error: 2.4603 - y2_output_root_mean_squared_error: 3.1355 - val_loss: 12.5494 - val_y1_output_loss: 5.9703 - val_y2_output_loss: 6.6264 - val_y1_output_root_mean_squared_error: 2.3842 - val_y2_output_root_mean_squared_error: 2.6201
# Epoch 17/500
# 614/614 [==============================] - 0s 469us/sample - loss: 17.3036 - y1_output_loss: 6.3797 - y2_output_loss: 10.9493 - y1_output_root_mean_squared_error: 2.5309 - y2_output_root_mean_squared_error: 3.3012 - val_loss: 37.3311 - val_y1_output_loss: 11.2072 - val_y2_output_loss: 26.7756 - val_y1_output_root_mean_squared_error: 3.3629 - val_y2_output_root_mean_squared_error: 5.1011
# Epoch 18/500
# 614/614 [==============================] - 0s 369us/sample - loss: 19.7252 - y1_output_loss: 6.6359 - y2_output_loss: 12.9261 - y1_output_root_mean_squared_error: 2.5842 - y2_output_root_mean_squared_error: 3.6121 - val_loss: 12.5885 - val_y1_output_loss: 6.4524 - val_y2_output_loss: 6.8682 - val_y1_output_root_mean_squared_error: 2.4193 - val_y2_output_root_mean_squared_error: 2.5952
# Epoch 19/500
# 614/614 [==============================] - 0s 471us/sample - loss: 14.4480 - y1_output_loss: 5.3132 - y2_output_loss: 9.0284 - y1_output_root_mean_squared_error: 2.3139 - y2_output_root_mean_squared_error: 3.0156 - val_loss: 9.9075 - val_y1_output_loss: 4.8899 - val_y2_output_loss: 5.0455 - val_y1_output_root_mean_squared_error: 2.1686 - val_y2_output_root_mean_squared_error: 2.2814
# Epoch 20/500
# 614/614 [==============================] - 0s 464us/sample - loss: 14.4940 - y1_output_loss: 5.1140 - y2_output_loss: 9.4251 - y1_output_root_mean_squared_error: 2.2646 - y2_output_root_mean_squared_error: 3.0603 - val_loss: 46.2437 - val_y1_output_loss: 15.8908 - val_y2_output_loss: 35.1969 - val_y1_output_root_mean_squared_error: 3.6991 - val_y2_output_root_mean_squared_error: 5.7061
# Epoch 21/500
# 614/614 [==============================] - 0s 366us/sample - loss: 14.3317 - y1_output_loss: 5.0822 - y2_output_loss: 9.2080 - y1_output_root_mean_squared_error: 2.2497 - y2_output_root_mean_squared_error: 3.0448 - val_loss: 13.5787 - val_y1_output_loss: 6.3316 - val_y2_output_loss: 7.6563 - val_y1_output_root_mean_squared_error: 2.4187 - val_y2_output_root_mean_squared_error: 2.7800
# Epoch 22/500
# 614/614 [==============================] - 0s 476us/sample - loss: 13.4584 - y1_output_loss: 5.1572 - y2_output_loss: 8.5875 - y1_output_root_mean_squared_error: 2.2345 - y2_output_root_mean_squared_error: 2.9096 - val_loss: 40.8188 - val_y1_output_loss: 10.6008 - val_y2_output_loss: 30.5841 - val_y1_output_root_mean_squared_error: 3.2516 - val_y2_output_root_mean_squared_error: 5.4997
# Epoch 23/500
# 614/614 [==============================] - 0s 474us/sample - loss: 13.5888 - y1_output_loss: 5.0777 - y2_output_loss: 8.6365 - y1_output_root_mean_squared_error: 2.2461 - y2_output_root_mean_squared_error: 2.9230 - val_loss: 27.4886 - val_y1_output_loss: 9.4075 - val_y2_output_loss: 19.3961 - val_y1_output_root_mean_squared_error: 2.9574 - val_y2_output_root_mean_squared_error: 4.3293
# Epoch 24/500
# 614/614 [==============================] - 0s 473us/sample - loss: 12.6161 - y1_output_loss: 4.4731 - y2_output_loss: 8.0609 - y1_output_root_mean_squared_error: 2.1199 - y2_output_root_mean_squared_error: 2.8499 - val_loss: 11.8072 - val_y1_output_loss: 5.5241 - val_y2_output_loss: 7.0559 - val_y1_output_root_mean_squared_error: 2.2145 - val_y2_output_root_mean_squared_error: 2.6274
# Epoch 25/500
# 614/614 [==============================] - 0s 369us/sample - loss: 12.6178 - y1_output_loss: 4.5150 - y2_output_loss: 8.3728 - y1_output_root_mean_squared_error: 2.0972 - y2_output_root_mean_squared_error: 2.8670 - val_loss: 25.0311 - val_y1_output_loss: 8.5921 - val_y2_output_loss: 16.4420 - val_y1_output_root_mean_squared_error: 2.9232 - val_y2_output_root_mean_squared_error: 4.0603
# Epoch 26/500
# 614/614 [==============================] - 0s 473us/sample - loss: 12.3481 - y1_output_loss: 4.3541 - y2_output_loss: 8.0123 - y1_output_root_mean_squared_error: 2.0801 - y2_output_root_mean_squared_error: 2.8322 - val_loss: 16.8164 - val_y1_output_loss: 4.2216 - val_y2_output_loss: 12.7056 - val_y1_output_root_mean_squared_error: 2.0539 - val_y2_output_root_mean_squared_error: 3.5493
# Epoch 27/500
# 614/614 [==============================] - 0s 475us/sample - loss: 9.1945 - y1_output_loss: 3.3031 - y2_output_loss: 5.8659 - y1_output_root_mean_squared_error: 1.8121 - y2_output_root_mean_squared_error: 2.4312 - val_loss: 9.6333 - val_y1_output_loss: 4.6168 - val_y2_output_loss: 5.7418 - val_y1_output_root_mean_squared_error: 2.0068 - val_y2_output_root_mean_squared_error: 2.3677
# Epoch 28/500
# 614/614 [==============================] - 0s 469us/sample - loss: 14.1671 - y1_output_loss: 4.5808 - y2_output_loss: 9.5530 - y1_output_root_mean_squared_error: 2.1445 - y2_output_root_mean_squared_error: 3.0932 - val_loss: 11.9073 - val_y1_output_loss: 3.5940 - val_y2_output_loss: 8.3862 - val_y1_output_root_mean_squared_error: 1.8697 - val_y2_output_root_mean_squared_error: 2.9003
# Epoch 29/500
# 614/614 [==============================] - 0s 368us/sample - loss: 10.5829 - y1_output_loss: 3.5214 - y2_output_loss: 6.9768 - y1_output_root_mean_squared_error: 1.8853 - y2_output_root_mean_squared_error: 2.6511 - val_loss: 9.5519 - val_y1_output_loss: 3.8520 - val_y2_output_loss: 5.8551 - val_y1_output_root_mean_squared_error: 1.8834 - val_y2_output_root_mean_squared_error: 2.4504
# Epoch 30/500
# 614/614 [==============================] - 0s 471us/sample - loss: 10.3591 - y1_output_loss: 3.6383 - y2_output_loss: 6.6704 - y1_output_root_mean_squared_error: 1.9148 - y2_output_root_mean_squared_error: 2.5870 - val_loss: 8.4914 - val_y1_output_loss: 3.9608 - val_y2_output_loss: 5.1151 - val_y1_output_root_mean_squared_error: 1.8572 - val_y2_output_root_mean_squared_error: 2.2455
# Epoch 31/500
# 614/614 [==============================] - 0s 471us/sample - loss: 8.4833 - y1_output_loss: 2.9427 - y2_output_loss: 5.4783 - y1_output_root_mean_squared_error: 1.7205 - y2_output_root_mean_squared_error: 2.3502 - val_loss: 6.8594 - val_y1_output_loss: 3.0216 - val_y2_output_loss: 3.9182 - val_y1_output_root_mean_squared_error: 1.6735 - val_y2_output_root_mean_squared_error: 2.0146
# Epoch 32/500
# 614/614 [==============================] - 0s 465us/sample - loss: 8.4071 - y1_output_loss: 2.8276 - y2_output_loss: 5.6237 - y1_output_root_mean_squared_error: 1.6879 - y2_output_root_mean_squared_error: 2.3575 - val_loss: 9.2029 - val_y1_output_loss: 4.4655 - val_y2_output_loss: 5.4581 - val_y1_output_root_mean_squared_error: 1.9712 - val_y2_output_root_mean_squared_error: 2.3059
# Epoch 33/500
# 614/614 [==============================] - 0s 366us/sample - loss: 9.5623 - y1_output_loss: 3.1635 - y2_output_loss: 6.3645 - y1_output_root_mean_squared_error: 1.7792 - y2_output_root_mean_squared_error: 2.5292 - val_loss: 8.1209 - val_y1_output_loss: 3.6333 - val_y2_output_loss: 4.8316 - val_y1_output_root_mean_squared_error: 1.7921 - val_y2_output_root_mean_squared_error: 2.2157
# Epoch 34/500
# 614/614 [==============================] - 0s 473us/sample - loss: 7.8893 - y1_output_loss: 2.4378 - y2_output_loss: 5.4038 - y1_output_root_mean_squared_error: 1.5682 - y2_output_root_mean_squared_error: 2.3302 - val_loss: 6.7738 - val_y1_output_loss: 3.0225 - val_y2_output_loss: 3.9351 - val_y1_output_root_mean_squared_error: 1.6505 - val_y2_output_root_mean_squared_error: 2.0123
# Epoch 35/500
# 614/614 [==============================] - 0s 471us/sample - loss: 8.1363 - y1_output_loss: 2.5604 - y2_output_loss: 5.5564 - y1_output_root_mean_squared_error: 1.5901 - y2_output_root_mean_squared_error: 2.3681 - val_loss: 8.0197 - val_y1_output_loss: 3.1165 - val_y2_output_loss: 5.0573 - val_y1_output_root_mean_squared_error: 1.6778 - val_y2_output_root_mean_squared_error: 2.2814
# Epoch 36/500
# 614/614 [==============================] - 0s 365us/sample - loss: 8.8261 - y1_output_loss: 2.7476 - y2_output_loss: 6.0610 - y1_output_root_mean_squared_error: 1.6644 - y2_output_root_mean_squared_error: 2.4608 - val_loss: 15.4866 - val_y1_output_loss: 5.1280 - val_y2_output_loss: 12.0808 - val_y1_output_root_mean_squared_error: 2.0433 - val_y2_output_root_mean_squared_error: 3.3633
# Epoch 37/500
# 614/614 [==============================] - 0s 473us/sample - loss: 10.0079 - y1_output_loss: 3.4160 - y2_output_loss: 6.5192 - y1_output_root_mean_squared_error: 1.8543 - y2_output_root_mean_squared_error: 2.5631 - val_loss: 7.7689 - val_y1_output_loss: 3.5145 - val_y2_output_loss: 4.2349 - val_y1_output_root_mean_squared_error: 1.8406 - val_y2_output_root_mean_squared_error: 2.0931
# Epoch 38/500
# 614/614 [==============================] - 0s 470us/sample - loss: 7.2055 - y1_output_loss: 2.4795 - y2_output_loss: 4.7109 - y1_output_root_mean_squared_error: 1.5792 - y2_output_root_mean_squared_error: 2.1706 - val_loss: 6.6678 - val_y1_output_loss: 2.8645 - val_y2_output_loss: 3.8768 - val_y1_output_root_mean_squared_error: 1.6286 - val_y2_output_root_mean_squared_error: 2.0039
# Epoch 39/500
# 614/614 [==============================] - 0s 468us/sample - loss: 7.2971 - y1_output_loss: 2.2393 - y2_output_loss: 5.0213 - y1_output_root_mean_squared_error: 1.5034 - y2_output_root_mean_squared_error: 2.2443 - val_loss: 7.9003 - val_y1_output_loss: 3.7946 - val_y2_output_loss: 4.7973 - val_y1_output_root_mean_squared_error: 1.7868 - val_y2_output_root_mean_squared_error: 2.1697
# Epoch 40/500
# 614/614 [==============================] - 0s 369us/sample - loss: 7.1003 - y1_output_loss: 2.2782 - y2_output_loss: 4.7983 - y1_output_root_mean_squared_error: 1.5032 - y2_output_root_mean_squared_error: 2.2002 - val_loss: 7.6012 - val_y1_output_loss: 3.0451 - val_y2_output_loss: 4.5616 - val_y1_output_root_mean_squared_error: 1.7176 - val_y2_output_root_mean_squared_error: 2.1566
# Epoch 41/500
# 614/614 [==============================] - 0s 469us/sample - loss: 7.3042 - y1_output_loss: 2.2461 - y2_output_loss: 5.0685 - y1_output_root_mean_squared_error: 1.5033 - y2_output_root_mean_squared_error: 2.2459 - val_loss: 26.5279 - val_y1_output_loss: 5.6259 - val_y2_output_loss: 22.7732 - val_y1_output_root_mean_squared_error: 2.1955 - val_y2_output_root_mean_squared_error: 4.6591
# Epoch 42/500
# 614/614 [==============================] - 0s 470us/sample - loss: 9.4657 - y1_output_loss: 3.0589 - y2_output_loss: 6.4454 - y1_output_root_mean_squared_error: 1.7499 - y2_output_root_mean_squared_error: 2.5305 - val_loss: 20.3079 - val_y1_output_loss: 7.1380 - val_y2_output_loss: 14.5995 - val_y1_output_root_mean_squared_error: 2.5176 - val_y2_output_root_mean_squared_error: 3.7376
# Epoch 43/500
# 614/614 [==============================] - 0s 365us/sample - loss: 9.9262 - y1_output_loss: 3.1254 - y2_output_loss: 6.7260 - y1_output_root_mean_squared_error: 1.7750 - y2_output_root_mean_squared_error: 2.6030 - val_loss: 9.2792 - val_y1_output_loss: 4.5435 - val_y2_output_loss: 5.8587 - val_y1_output_root_mean_squared_error: 1.9245 - val_y2_output_root_mean_squared_error: 2.3612
# Epoch 44/500
# 614/614 [==============================] - 0s 469us/sample - loss: 8.9160 - y1_output_loss: 2.8618 - y2_output_loss: 5.9960 - y1_output_root_mean_squared_error: 1.6974 - y2_output_root_mean_squared_error: 2.4566 - val_loss: 9.2201 - val_y1_output_loss: 3.9831 - val_y2_output_loss: 5.5428 - val_y1_output_root_mean_squared_error: 1.8949 - val_y2_output_root_mean_squared_error: 2.3726
# Epoch 45/500
# 614/614 [==============================] - 0s 471us/sample - loss: 7.1316 - y1_output_loss: 2.1260 - y2_output_loss: 4.9831 - y1_output_root_mean_squared_error: 1.4634 - y2_output_root_mean_squared_error: 2.2338 - val_loss: 12.0808 - val_y1_output_loss: 4.1758 - val_y2_output_loss: 9.2222 - val_y1_output_root_mean_squared_error: 1.8404 - val_y2_output_root_mean_squared_error: 2.9485
# Epoch 46/500
# 614/614 [==============================] - 0s 469us/sample - loss: 6.1752 - y1_output_loss: 1.9657 - y2_output_loss: 4.1896 - y1_output_root_mean_squared_error: 1.4039 - y2_output_root_mean_squared_error: 2.0504 - val_loss: 11.0074 - val_y1_output_loss: 3.9938 - val_y2_output_loss: 7.0624 - val_y1_output_root_mean_squared_error: 1.9532 - val_y2_output_root_mean_squared_error: 2.6819
# Epoch 47/500
# 614/614 [==============================] - 0s 365us/sample - loss: 7.4792 - y1_output_loss: 2.3520 - y2_output_loss: 5.0817 - y1_output_root_mean_squared_error: 1.5367 - y2_output_root_mean_squared_error: 2.2622 - val_loss: 6.6449 - val_y1_output_loss: 2.6550 - val_y2_output_loss: 4.0870 - val_y1_output_root_mean_squared_error: 1.5582 - val_y2_output_root_mean_squared_error: 2.0535
# Epoch 48/500
# 614/614 [==============================] - 0s 467us/sample - loss: 6.8764 - y1_output_loss: 2.0907 - y2_output_loss: 4.7261 - y1_output_root_mean_squared_error: 1.4521 - y2_output_root_mean_squared_error: 2.1836 - val_loss: 6.0313 - val_y1_output_loss: 2.4146 - val_y2_output_loss: 3.7608 - val_y1_output_root_mean_squared_error: 1.4689 - val_y2_output_root_mean_squared_error: 1.9681
# Epoch 49/500
# 614/614 [==============================] - 0s 466us/sample - loss: 6.3478 - y1_output_loss: 1.9706 - y2_output_loss: 4.3371 - y1_output_root_mean_squared_error: 1.4062 - y2_output_root_mean_squared_error: 2.0906 - val_loss: 6.3754 - val_y1_output_loss: 2.7835 - val_y2_output_loss: 3.9023 - val_y1_output_root_mean_squared_error: 1.5516 - val_y2_output_root_mean_squared_error: 1.9920
# Epoch 50/500
# 614/614 [==============================] - 0s 370us/sample - loss: 7.7519 - y1_output_loss: 2.2243 - y2_output_loss: 5.5672 - y1_output_root_mean_squared_error: 1.4965 - y2_output_root_mean_squared_error: 2.3479 - val_loss: 6.7663 - val_y1_output_loss: 2.2995 - val_y2_output_loss: 4.5842 - val_y1_output_root_mean_squared_error: 1.4567 - val_y2_output_root_mean_squared_error: 2.1550
# Epoch 51/500
# 614/614 [==============================] - 0s 468us/sample - loss: 7.8778 - y1_output_loss: 2.2185 - y2_output_loss: 5.6069 - y1_output_root_mean_squared_error: 1.4927 - y2_output_root_mean_squared_error: 2.3769 - val_loss: 8.4799 - val_y1_output_loss: 3.1807 - val_y2_output_loss: 5.3973 - val_y1_output_root_mean_squared_error: 1.7217 - val_y2_output_root_mean_squared_error: 2.3485
# Epoch 52/500
# 614/614 [==============================] - 0s 469us/sample - loss: 10.5849 - y1_output_loss: 3.1094 - y2_output_loss: 7.4270 - y1_output_root_mean_squared_error: 1.7710 - y2_output_root_mean_squared_error: 2.7292 - val_loss: 12.4675 - val_y1_output_loss: 3.9291 - val_y2_output_loss: 8.9982 - val_y1_output_root_mean_squared_error: 1.9125 - val_y2_output_root_mean_squared_error: 2.9681
# Epoch 53/500
# 614/614 [==============================] - 0s 366us/sample - loss: 7.5337 - y1_output_loss: 2.1733 - y2_output_loss: 5.3164 - y1_output_root_mean_squared_error: 1.4740 - y2_output_root_mean_squared_error: 2.3154 - val_loss: 6.0384 - val_y1_output_loss: 2.6924 - val_y2_output_loss: 3.6973 - val_y1_output_root_mean_squared_error: 1.5127 - val_y2_output_root_mean_squared_error: 1.9366
# Epoch 54/500
# 614/614 [==============================] - 0s 472us/sample - loss: 5.2315 - y1_output_loss: 1.6857 - y2_output_loss: 3.5525 - y1_output_root_mean_squared_error: 1.3012 - y2_output_root_mean_squared_error: 1.8810 - val_loss: 9.3919 - val_y1_output_loss: 2.9028 - val_y2_output_loss: 6.5841 - val_y1_output_root_mean_squared_error: 1.6413 - val_y2_output_root_mean_squared_error: 2.5881
# Epoch 55/500
# 614/614 [==============================] - 0s 467us/sample - loss: 6.7836 - y1_output_loss: 2.1488 - y2_output_loss: 4.6117 - y1_output_root_mean_squared_error: 1.4691 - y2_output_root_mean_squared_error: 2.1507 - val_loss: 5.6714 - val_y1_output_loss: 2.4127 - val_y2_output_loss: 3.4531 - val_y1_output_root_mean_squared_error: 1.4623 - val_y2_output_root_mean_squared_error: 1.8796
# Epoch 56/500
# 614/614 [==============================] - 0s 366us/sample - loss: 7.0992 - y1_output_loss: 2.2361 - y2_output_loss: 5.0383 - y1_output_root_mean_squared_error: 1.4644 - y2_output_root_mean_squared_error: 2.2260 - val_loss: 31.1485 - val_y1_output_loss: 13.3512 - val_y2_output_loss: 21.0480 - val_y1_output_root_mean_squared_error: 3.3921 - val_y2_output_root_mean_squared_error: 4.4319
# Epoch 57/500
# 614/614 [==============================] - 0s 465us/sample - loss: 6.5723 - y1_output_loss: 2.0130 - y2_output_loss: 4.5302 - y1_output_root_mean_squared_error: 1.4209 - y2_output_root_mean_squared_error: 2.1338 - val_loss: 11.8607 - val_y1_output_loss: 3.9672 - val_y2_output_loss: 7.9362 - val_y1_output_root_mean_squared_error: 1.9672 - val_y2_output_root_mean_squared_error: 2.8268
# Epoch 58/500
# 614/614 [==============================] - 0s 467us/sample - loss: 5.1865 - y1_output_loss: 1.6034 - y2_output_loss: 3.5666 - y1_output_root_mean_squared_error: 1.2617 - y2_output_root_mean_squared_error: 1.8960 - val_loss: 5.3706 - val_y1_output_loss: 2.1662 - val_y2_output_loss: 3.3177 - val_y1_output_root_mean_squared_error: 1.3942 - val_y2_output_root_mean_squared_error: 1.8512
# Epoch 59/500
# 614/614 [==============================] - 0s 216us/sample - loss: 6.1027 - y1_output_loss: 1.7652 - y2_output_loss: 4.3008 - y1_output_root_mean_squared_error: 1.3343 - y2_output_root_mean_squared_error: 2.0791 - val_loss: 6.1562 - val_y1_output_loss: 2.4168 - val_y2_output_loss: 3.8742 - val_y1_output_root_mean_squared_error: 1.4885 - val_y2_output_root_mean_squared_error: 1.9851
# Epoch 60/500
# 614/614 [==============================] - 0s 267us/sample - loss: 6.2943 - y1_output_loss: 1.8226 - y2_output_loss: 4.4707 - y1_output_root_mean_squared_error: 1.3524 - y2_output_root_mean_squared_error: 2.1131 - val_loss: 5.2989 - val_y1_output_loss: 2.0672 - val_y2_output_loss: 3.2990 - val_y1_output_root_mean_squared_error: 1.3739 - val_y2_output_root_mean_squared_error: 1.8470
# Epoch 61/500
# 614/614 [==============================] - 0s 221us/sample - loss: 5.7420 - y1_output_loss: 1.7552 - y2_output_loss: 4.0690 - y1_output_root_mean_squared_error: 1.3006 - y2_output_root_mean_squared_error: 2.0125 - val_loss: 11.9790 - val_y1_output_loss: 4.2667 - val_y2_output_loss: 7.5742 - val_y1_output_root_mean_squared_error: 2.0481 - val_y2_output_root_mean_squared_error: 2.7900
# Epoch 62/500
# 614/614 [==============================] - 0s 307us/sample - loss: 5.9198 - y1_output_loss: 1.8497 - y2_output_loss: 4.0412 - y1_output_root_mean_squared_error: 1.3640 - y2_output_root_mean_squared_error: 2.0148 - val_loss: 8.7137 - val_y1_output_loss: 2.3890 - val_y2_output_loss: 6.4712 - val_y1_output_root_mean_squared_error: 1.4948 - val_y2_output_root_mean_squared_error: 2.5455
# Epoch 63/500
# 614/614 [==============================] - 0s 178us/sample - loss: 5.3454 - y1_output_loss: 1.4220 - y2_output_loss: 3.9326 - y1_output_root_mean_squared_error: 1.1954 - y2_output_root_mean_squared_error: 1.9790 - val_loss: 6.8094 - val_y1_output_loss: 2.1938 - val_y2_output_loss: 5.0968 - val_y1_output_root_mean_squared_error: 1.3380 - val_y2_output_root_mean_squared_error: 2.2404
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.9030 - y1_output_loss: 1.3343 - y2_output_loss: 3.5555 - y1_output_root_mean_squared_error: 1.1502 - y2_output_root_mean_squared_error: 1.8921 - val_loss: 5.4586 - val_y1_output_loss: 2.0327 - val_y2_output_loss: 3.5862 - val_y1_output_root_mean_squared_error: 1.3555 - val_y2_output_root_mean_squared_error: 1.9030
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.9458 - y1_output_loss: 1.8708 - y2_output_loss: 4.1460 - y1_output_root_mean_squared_error: 1.3667 - y2_output_root_mean_squared_error: 2.0194 - val_loss: 15.2414 - val_y1_output_loss: 4.8953 - val_y2_output_loss: 12.0766 - val_y1_output_root_mean_squared_error: 1.9891 - val_y2_output_root_mean_squared_error: 3.3593
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4918 - y1_output_loss: 1.2938 - y2_output_loss: 3.2683 - y1_output_root_mean_squared_error: 1.1420 - y2_output_root_mean_squared_error: 1.7854 - val_loss: 8.8221 - val_y1_output_loss: 2.1905 - val_y2_output_loss: 6.7704 - val_y1_output_root_mean_squared_error: 1.4456 - val_y2_output_root_mean_squared_error: 2.5947
# Epoch 67/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.7124 - y1_output_loss: 1.6904 - y2_output_loss: 4.0582 - y1_output_root_mean_squared_error: 1.3035 - y2_output_root_mean_squared_error: 2.0033 - val_loss: 7.0132 - val_y1_output_loss: 1.9342 - val_y2_output_loss: 5.2679 - val_y1_output_root_mean_squared_error: 1.2691 - val_y2_output_root_mean_squared_error: 2.3243
# Epoch 68/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.3518 - y1_output_loss: 2.3246 - y2_output_loss: 6.0353 - y1_output_root_mean_squared_error: 1.5294 - y2_output_root_mean_squared_error: 2.4521 - val_loss: 7.0843 - val_y1_output_loss: 1.6871 - val_y2_output_loss: 5.3821 - val_y1_output_root_mean_squared_error: 1.2660 - val_y2_output_root_mean_squared_error: 2.3413
# Epoch 69/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.4297 - y1_output_loss: 1.2864 - y2_output_loss: 3.1173 - y1_output_root_mean_squared_error: 1.1389 - y2_output_root_mean_squared_error: 1.7699 - val_loss: 4.4892 - val_y1_output_loss: 1.4551 - val_y2_output_loss: 3.1169 - val_y1_output_root_mean_squared_error: 1.1345 - val_y2_output_root_mean_squared_error: 1.7894
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.2131 - y1_output_loss: 1.1776 - y2_output_loss: 3.0565 - y1_output_root_mean_squared_error: 1.0827 - y2_output_root_mean_squared_error: 1.7438 - val_loss: 4.3254 - val_y1_output_loss: 1.9132 - val_y2_output_loss: 2.7494 - val_y1_output_root_mean_squared_error: 1.2595 - val_y2_output_root_mean_squared_error: 1.6550
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.6186 - y1_output_loss: 1.5255 - y2_output_loss: 4.0733 - y1_output_root_mean_squared_error: 1.2294 - y2_output_root_mean_squared_error: 2.0266 - val_loss: 3.9004 - val_y1_output_loss: 1.6482 - val_y2_output_loss: 2.4718 - val_y1_output_root_mean_squared_error: 1.1900 - val_y2_output_root_mean_squared_error: 1.5761
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5052 - y1_output_loss: 1.6690 - y2_output_loss: 3.8296 - y1_output_root_mean_squared_error: 1.2963 - y2_output_root_mean_squared_error: 1.9557 - val_loss: 4.6992 - val_y1_output_loss: 2.5427 - val_y2_output_loss: 3.0905 - val_y1_output_root_mean_squared_error: 1.3603 - val_y2_output_root_mean_squared_error: 1.6878
# Epoch 73/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5795 - y1_output_loss: 1.0057 - y2_output_loss: 2.5741 - y1_output_root_mean_squared_error: 0.9955 - y2_output_root_mean_squared_error: 1.6089 - val_loss: 3.9434 - val_y1_output_loss: 1.4688 - val_y2_output_loss: 2.6127 - val_y1_output_root_mean_squared_error: 1.1100 - val_y2_output_root_mean_squared_error: 1.6466
# Epoch 74/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.8010 - y1_output_loss: 1.1110 - y2_output_loss: 3.6733 - y1_output_root_mean_squared_error: 1.0473 - y2_output_root_mean_squared_error: 1.9246 - val_loss: 4.1238 - val_y1_output_loss: 2.0628 - val_y2_output_loss: 2.5290 - val_y1_output_root_mean_squared_error: 1.2744 - val_y2_output_root_mean_squared_error: 1.5810
# Epoch 75/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.8480 - y1_output_loss: 1.0785 - y2_output_loss: 2.7899 - y1_output_root_mean_squared_error: 1.0405 - y2_output_root_mean_squared_error: 1.6630 - val_loss: 3.2219 - val_y1_output_loss: 1.4096 - val_y2_output_loss: 1.9499 - val_y1_output_root_mean_squared_error: 1.1051 - val_y2_output_root_mean_squared_error: 1.4144
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.1984 - y1_output_loss: 2.3590 - y2_output_loss: 5.8875 - y1_output_root_mean_squared_error: 1.5397 - y2_output_root_mean_squared_error: 2.4140 - val_loss: 7.1351 - val_y1_output_loss: 1.9691 - val_y2_output_loss: 5.5355 - val_y1_output_root_mean_squared_error: 1.3207 - val_y2_output_root_mean_squared_error: 2.3218
# Epoch 77/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.0179 - y1_output_loss: 1.3491 - y2_output_loss: 3.6779 - y1_output_root_mean_squared_error: 1.1621 - y2_output_root_mean_squared_error: 1.9150 - val_loss: 5.2971 - val_y1_output_loss: 2.9450 - val_y2_output_loss: 3.1933 - val_y1_output_root_mean_squared_error: 1.4993 - val_y2_output_root_mean_squared_error: 1.7462
# Epoch 78/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.8791 - y1_output_loss: 0.9589 - y2_output_loss: 2.9421 - y1_output_root_mean_squared_error: 0.9641 - y2_output_root_mean_squared_error: 1.7175 - val_loss: 6.2685 - val_y1_output_loss: 2.3377 - val_y2_output_loss: 4.3119 - val_y1_output_root_mean_squared_error: 1.4917 - val_y2_output_root_mean_squared_error: 2.0108
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7183 - y1_output_loss: 1.0173 - y2_output_loss: 2.6740 - y1_output_root_mean_squared_error: 1.0128 - y2_output_root_mean_squared_error: 1.6409 - val_loss: 3.5317 - val_y1_output_loss: 1.0830 - val_y2_output_loss: 2.4711 - val_y1_output_root_mean_squared_error: 1.0012 - val_y2_output_root_mean_squared_error: 1.5904
# Epoch 80/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.2318 - y1_output_loss: 1.3644 - y2_output_loss: 4.8334 - y1_output_root_mean_squared_error: 1.1704 - y2_output_root_mean_squared_error: 2.2050 - val_loss: 3.4216 - val_y1_output_loss: 1.7665 - val_y2_output_loss: 1.9831 - val_y1_output_root_mean_squared_error: 1.1792 - val_y2_output_root_mean_squared_error: 1.4251
# Epoch 81/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.3221 - y1_output_loss: 0.9904 - y2_output_loss: 3.3055 - y1_output_root_mean_squared_error: 0.9984 - y2_output_root_mean_squared_error: 1.8235 - val_loss: 3.4596 - val_y1_output_loss: 1.2981 - val_y2_output_loss: 2.2449 - val_y1_output_root_mean_squared_error: 1.0635 - val_y2_output_root_mean_squared_error: 1.5260
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4374 - y1_output_loss: 0.8075 - y2_output_loss: 2.6363 - y1_output_root_mean_squared_error: 0.8982 - y2_output_root_mean_squared_error: 1.6219 - val_loss: 5.0099 - val_y1_output_loss: 2.0282 - val_y2_output_loss: 3.4218 - val_y1_output_root_mean_squared_error: 1.2422 - val_y2_output_root_mean_squared_error: 1.8620
# Epoch 83/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3490 - y1_output_loss: 0.8035 - y2_output_loss: 2.6186 - y1_output_root_mean_squared_error: 0.8999 - y2_output_root_mean_squared_error: 1.5935 - val_loss: 20.3759 - val_y1_output_loss: 2.9062 - val_y2_output_loss: 17.9362 - val_y1_output_root_mean_squared_error: 1.6760 - val_y2_output_root_mean_squared_error: 4.1913
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.5292 - y1_output_loss: 2.2260 - y2_output_loss: 5.2693 - y1_output_root_mean_squared_error: 1.4895 - y2_output_root_mean_squared_error: 2.3045 - val_loss: 2.9748 - val_y1_output_loss: 1.2218 - val_y2_output_loss: 1.9402 - val_y1_output_root_mean_squared_error: 0.9819 - val_y2_output_root_mean_squared_error: 1.4180
# Epoch 85/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9686 - y1_output_loss: 0.6553 - y2_output_loss: 2.2995 - y1_output_root_mean_squared_error: 0.8090 - y2_output_root_mean_squared_error: 1.5212 - val_loss: 3.2901 - val_y1_output_loss: 1.0838 - val_y2_output_loss: 2.2550 - val_y1_output_root_mean_squared_error: 0.9952 - val_y2_output_root_mean_squared_error: 1.5165
# Epoch 86/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2389 - y1_output_loss: 0.7702 - y2_output_loss: 2.4654 - y1_output_root_mean_squared_error: 0.8805 - y2_output_root_mean_squared_error: 1.5696 - val_loss: 5.6260 - val_y1_output_loss: 1.1917 - val_y2_output_loss: 4.5199 - val_y1_output_root_mean_squared_error: 1.0571 - val_y2_output_root_mean_squared_error: 2.1233
# Epoch 87/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9556 - y1_output_loss: 0.7572 - y2_output_loss: 2.1923 - y1_output_root_mean_squared_error: 0.8726 - y2_output_root_mean_squared_error: 1.4813 - val_loss: 4.7993 - val_y1_output_loss: 1.1407 - val_y2_output_loss: 3.7432 - val_y1_output_root_mean_squared_error: 1.0262 - val_y2_output_root_mean_squared_error: 1.9355
# Epoch 88/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0432 - y1_output_loss: 0.6846 - y2_output_loss: 2.3741 - y1_output_root_mean_squared_error: 0.8219 - y2_output_root_mean_squared_error: 1.5387 - val_loss: 4.0198 - val_y1_output_loss: 2.2917 - val_y2_output_loss: 2.2992 - val_y1_output_root_mean_squared_error: 1.3209 - val_y2_output_root_mean_squared_error: 1.5083
# Epoch 89/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3839 - y1_output_loss: 0.7884 - y2_output_loss: 2.6099 - y1_output_root_mean_squared_error: 0.8823 - y2_output_root_mean_squared_error: 1.6142 - val_loss: 10.8989 - val_y1_output_loss: 4.0247 - val_y2_output_loss: 7.1671 - val_y1_output_root_mean_squared_error: 1.9826 - val_y2_output_root_mean_squared_error: 2.6397
# Epoch 90/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.6894 - y1_output_loss: 1.3386 - y2_output_loss: 3.3558 - y1_output_root_mean_squared_error: 1.1621 - y2_output_root_mean_squared_error: 1.8273 - val_loss: 3.4030 - val_y1_output_loss: 1.4371 - val_y2_output_loss: 2.2305 - val_y1_output_root_mean_squared_error: 1.0562 - val_y2_output_root_mean_squared_error: 1.5124
# Epoch 91/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0231 - y1_output_loss: 0.7001 - y2_output_loss: 2.2963 - y1_output_root_mean_squared_error: 0.8397 - y2_output_root_mean_squared_error: 1.5225 - val_loss: 2.5080 - val_y1_output_loss: 0.7890 - val_y2_output_loss: 1.7687 - val_y1_output_root_mean_squared_error: 0.8373 - val_y2_output_root_mean_squared_error: 1.3442
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7156 - y1_output_loss: 0.6694 - y2_output_loss: 2.1282 - y1_output_root_mean_squared_error: 0.8061 - y2_output_root_mean_squared_error: 1.4373 - val_loss: 13.1917 - val_y1_output_loss: 4.3139 - val_y2_output_loss: 9.0902 - val_y1_output_root_mean_squared_error: 2.0464 - val_y2_output_root_mean_squared_error: 3.0007
# Epoch 93/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.5289 - y1_output_loss: 1.0296 - y2_output_loss: 3.4629 - y1_output_root_mean_squared_error: 1.0196 - y2_output_root_mean_squared_error: 1.8680 - val_loss: 3.3414 - val_y1_output_loss: 1.0671 - val_y2_output_loss: 2.3621 - val_y1_output_root_mean_squared_error: 1.0109 - val_y2_output_root_mean_squared_error: 1.5230
# Epoch 94/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.0138 - y1_output_loss: 0.7282 - y2_output_loss: 2.3032 - y1_output_root_mean_squared_error: 0.8530 - y2_output_root_mean_squared_error: 1.5120 - val_loss: 4.5931 - val_y1_output_loss: 0.9284 - val_y2_output_loss: 3.7640 - val_y1_output_root_mean_squared_error: 0.8875 - val_y2_output_root_mean_squared_error: 1.9508
# Epoch 95/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.9167 - y1_output_loss: 1.0521 - y2_output_loss: 2.8621 - y1_output_root_mean_squared_error: 1.0204 - y2_output_root_mean_squared_error: 1.6957 - val_loss: 4.4176 - val_y1_output_loss: 1.6691 - val_y2_output_loss: 3.0327 - val_y1_output_root_mean_squared_error: 1.2723 - val_y2_output_root_mean_squared_error: 1.6729
# Epoch 96/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3728 - y1_output_loss: 1.0808 - y2_output_loss: 3.3277 - y1_output_root_mean_squared_error: 1.0441 - y2_output_root_mean_squared_error: 1.8118 - val_loss: 7.9777 - val_y1_output_loss: 1.6019 - val_y2_output_loss: 6.7777 - val_y1_output_root_mean_squared_error: 1.1642 - val_y2_output_root_mean_squared_error: 2.5734
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0956 - y1_output_loss: 0.7868 - y2_output_loss: 2.3028 - y1_output_root_mean_squared_error: 0.8868 - y2_output_root_mean_squared_error: 1.5196 - val_loss: 8.8367 - val_y1_output_loss: 3.5954 - val_y2_output_loss: 6.4873 - val_y1_output_root_mean_squared_error: 1.6777 - val_y2_output_root_mean_squared_error: 2.4540
# Epoch 98/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1668 - y1_output_loss: 0.8064 - y2_output_loss: 2.3641 - y1_output_root_mean_squared_error: 0.8937 - y2_output_root_mean_squared_error: 1.5389 - val_loss: 3.4017 - val_y1_output_loss: 2.2742 - val_y2_output_loss: 1.6274 - val_y1_output_root_mean_squared_error: 1.3280 - val_y2_output_root_mean_squared_error: 1.2799
# Epoch 99/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6252 - y1_output_loss: 0.8888 - y2_output_loss: 2.7286 - y1_output_root_mean_squared_error: 0.9428 - y2_output_root_mean_squared_error: 1.6542 - val_loss: 2.9706 - val_y1_output_loss: 1.2483 - val_y2_output_loss: 1.9853 - val_y1_output_root_mean_squared_error: 1.0029 - val_y2_output_root_mean_squared_error: 1.4017
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1325 - y1_output_loss: 0.7025 - y2_output_loss: 2.4263 - y1_output_root_mean_squared_error: 0.8411 - y2_output_root_mean_squared_error: 1.5573 - val_loss: 5.1862 - val_y1_output_loss: 1.3150 - val_y2_output_loss: 4.1388 - val_y1_output_root_mean_squared_error: 1.0947 - val_y2_output_root_mean_squared_error: 1.9970
# Epoch 101/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7591 - y1_output_loss: 0.8714 - y2_output_loss: 2.8849 - y1_output_root_mean_squared_error: 0.9364 - y2_output_root_mean_squared_error: 1.6977 - val_loss: 4.6270 - val_y1_output_loss: 2.2330 - val_y2_output_loss: 2.8810 - val_y1_output_root_mean_squared_error: 1.3391 - val_y2_output_root_mean_squared_error: 1.6834
# Epoch 102/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.0114 - y1_output_loss: 0.7852 - y2_output_loss: 2.2080 - y1_output_root_mean_squared_error: 0.8896 - y2_output_root_mean_squared_error: 1.4900 - val_loss: 2.3367 - val_y1_output_loss: 0.5892 - val_y2_output_loss: 1.7764 - val_y1_output_root_mean_squared_error: 0.7311 - val_y2_output_root_mean_squared_error: 1.3425
# Epoch 103/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8962 - y1_output_loss: 2.2253 - y2_output_loss: 5.5985 - y1_output_root_mean_squared_error: 1.4986 - y2_output_root_mean_squared_error: 2.3770 - val_loss: 2.4152 - val_y1_output_loss: 0.9800 - val_y2_output_loss: 1.5305 - val_y1_output_root_mean_squared_error: 0.9180 - val_y2_output_root_mean_squared_error: 1.2540
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7058 - y1_output_loss: 0.6329 - y2_output_loss: 2.0569 - y1_output_root_mean_squared_error: 0.7987 - y2_output_root_mean_squared_error: 1.4380 - val_loss: 3.1968 - val_y1_output_loss: 1.2074 - val_y2_output_loss: 2.1722 - val_y1_output_root_mean_squared_error: 1.0150 - val_y2_output_root_mean_squared_error: 1.4719
# Epoch 105/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2057 - y1_output_loss: 0.7280 - y2_output_loss: 2.4906 - y1_output_root_mean_squared_error: 0.8480 - y2_output_root_mean_squared_error: 1.5769 - val_loss: 3.5260 - val_y1_output_loss: 1.1845 - val_y2_output_loss: 2.4767 - val_y1_output_root_mean_squared_error: 1.0394 - val_y2_output_root_mean_squared_error: 1.5639
# Epoch 106/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.0638 - y1_output_loss: 0.7267 - y2_output_loss: 2.3122 - y1_output_root_mean_squared_error: 0.8556 - y2_output_root_mean_squared_error: 1.5270 - val_loss: 2.7841 - val_y1_output_loss: 1.0606 - val_y2_output_loss: 1.8350 - val_y1_output_root_mean_squared_error: 0.9502 - val_y2_output_root_mean_squared_error: 1.3716
# Epoch 107/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.2459 - y1_output_loss: 0.8859 - y2_output_loss: 2.3485 - y1_output_root_mean_squared_error: 0.9423 - y2_output_root_mean_squared_error: 1.5356 - val_loss: 2.1940 - val_y1_output_loss: 0.6192 - val_y2_output_loss: 1.6026 - val_y1_output_root_mean_squared_error: 0.7615 - val_y2_output_root_mean_squared_error: 1.2705
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0623 - y1_output_loss: 0.6891 - y2_output_loss: 2.3469 - y1_output_root_mean_squared_error: 0.8333 - y2_output_root_mean_squared_error: 1.5388 - val_loss: 2.2859 - val_y1_output_loss: 0.6424 - val_y2_output_loss: 1.6951 - val_y1_output_root_mean_squared_error: 0.7732 - val_y2_output_root_mean_squared_error: 1.2993
# Epoch 109/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.2732 - y1_output_loss: 0.5521 - y2_output_loss: 1.7427 - y1_output_root_mean_squared_error: 0.7403 - y2_output_root_mean_squared_error: 1.3135 - val_loss: 2.2741 - val_y1_output_loss: 0.7098 - val_y2_output_loss: 1.6148 - val_y1_output_root_mean_squared_error: 0.7956 - val_y2_output_root_mean_squared_error: 1.2811
# Epoch 110/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.7538 - y1_output_loss: 0.5685 - y2_output_loss: 2.2031 - y1_output_root_mean_squared_error: 0.7546 - y2_output_root_mean_squared_error: 1.4780 - val_loss: 7.4134 - val_y1_output_loss: 1.2353 - val_y2_output_loss: 6.7355 - val_y1_output_root_mean_squared_error: 0.9831 - val_y2_output_root_mean_squared_error: 2.5391
# Epoch 111/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.2016 - y1_output_loss: 1.0752 - y2_output_loss: 3.1001 - y1_output_root_mean_squared_error: 1.0401 - y2_output_root_mean_squared_error: 1.7663 - val_loss: 2.3559 - val_y1_output_loss: 0.9621 - val_y2_output_loss: 1.5481 - val_y1_output_root_mean_squared_error: 0.8872 - val_y2_output_root_mean_squared_error: 1.2525
# Epoch 112/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.9430 - y1_output_loss: 0.7450 - y2_output_loss: 2.1748 - y1_output_root_mean_squared_error: 0.8648 - y2_output_root_mean_squared_error: 1.4816 - val_loss: 2.1575 - val_y1_output_loss: 0.8781 - val_y2_output_loss: 1.4126 - val_y1_output_root_mean_squared_error: 0.8505 - val_y2_output_root_mean_squared_error: 1.1975
# Epoch 113/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.3069 - y1_output_loss: 0.7813 - y2_output_loss: 2.5348 - y1_output_root_mean_squared_error: 0.8828 - y2_output_root_mean_squared_error: 1.5898 - val_loss: 5.2615 - val_y1_output_loss: 3.1341 - val_y2_output_loss: 3.3395 - val_y1_output_root_mean_squared_error: 1.5050 - val_y2_output_root_mean_squared_error: 1.7310
# Epoch 114/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5122 - y1_output_loss: 0.6332 - y2_output_loss: 1.8980 - y1_output_root_mean_squared_error: 0.7952 - y2_output_root_mean_squared_error: 1.3711 - val_loss: 3.8112 - val_y1_output_loss: 1.0530 - val_y2_output_loss: 2.8088 - val_y1_output_root_mean_squared_error: 0.9839 - val_y2_output_root_mean_squared_error: 1.6862
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1848 - y1_output_loss: 0.7152 - y2_output_loss: 2.4413 - y1_output_root_mean_squared_error: 0.8489 - y2_output_root_mean_squared_error: 1.5698 - val_loss: 3.3941 - val_y1_output_loss: 1.3891 - val_y2_output_loss: 2.4405 - val_y1_output_root_mean_squared_error: 1.0272 - val_y2_output_root_mean_squared_error: 1.5294
# Epoch 116/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.7956 - y1_output_loss: 2.2876 - y2_output_loss: 6.4564 - y1_output_root_mean_squared_error: 1.5182 - y2_output_root_mean_squared_error: 2.5477 - val_loss: 2.6134 - val_y1_output_loss: 0.6659 - val_y2_output_loss: 2.0540 - val_y1_output_root_mean_squared_error: 0.8119 - val_y2_output_root_mean_squared_error: 1.3979
# Epoch 117/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.0898 - y1_output_loss: 0.9218 - y2_output_loss: 3.1390 - y1_output_root_mean_squared_error: 0.9630 - y2_output_root_mean_squared_error: 1.7783 - val_loss: 1.9198 - val_y1_output_loss: 0.5478 - val_y2_output_loss: 1.4009 - val_y1_output_root_mean_squared_error: 0.7253 - val_y2_output_root_mean_squared_error: 1.1806
# Epoch 118/500
# 614/614 [==============================] - 0s 124us/sample - loss: 1.9783 - y1_output_loss: 0.4581 - y2_output_loss: 1.5204 - y1_output_root_mean_squared_error: 0.6771 - y2_output_root_mean_squared_error: 1.2328 - val_loss: 3.3590 - val_y1_output_loss: 0.6028 - val_y2_output_loss: 2.8415 - val_y1_output_root_mean_squared_error: 0.7614 - val_y2_output_root_mean_squared_error: 1.6671
# Epoch 119/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.8814 - y1_output_loss: 0.6571 - y2_output_loss: 2.2091 - y1_output_root_mean_squared_error: 0.8109 - y2_output_root_mean_squared_error: 1.4912 - val_loss: 2.3903 - val_y1_output_loss: 0.6157 - val_y2_output_loss: 1.8077 - val_y1_output_root_mean_squared_error: 0.7662 - val_y2_output_root_mean_squared_error: 1.3428
# Epoch 120/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7628 - y1_output_loss: 0.7071 - y2_output_loss: 2.0404 - y1_output_root_mean_squared_error: 0.8389 - y2_output_root_mean_squared_error: 1.4350 - val_loss: 2.0136 - val_y1_output_loss: 0.7311 - val_y2_output_loss: 1.3009 - val_y1_output_root_mean_squared_error: 0.8349 - val_y2_output_root_mean_squared_error: 1.1474
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3656 - y1_output_loss: 0.1280 - y2_output_loss: 0.2347 - y1_output_root_mean_squared_error: 0.3595 - y2_output_root_mean_squared_error: 0.4862 - val_loss: 0.8582 - val_y1_output_loss: 0.3221 - val_y2_output_loss: 0.5528 - val_y1_output_root_mean_squared_error: 0.5361 - val_y2_output_root_mean_squared_error: 0.7555
# Epoch 462/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3935 - y1_output_loss: 0.1385 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.5042 - val_loss: 0.7952 - val_y1_output_loss: 0.3092 - val_y2_output_loss: 0.5232 - val_y1_output_root_mean_squared_error: 0.5174 - val_y2_output_root_mean_squared_error: 0.7263
# Epoch 463/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3451 - y1_output_loss: 0.1086 - y2_output_loss: 0.2335 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.4855 - val_loss: 0.7023 - val_y1_output_loss: 0.1626 - val_y2_output_loss: 0.5590 - val_y1_output_root_mean_squared_error: 0.3970 - val_y2_output_root_mean_squared_error: 0.7381
# Epoch 464/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4066 - y1_output_loss: 0.1390 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5182 - val_loss: 0.7427 - val_y1_output_loss: 0.2067 - val_y2_output_loss: 0.5511 - val_y1_output_root_mean_squared_error: 0.4319 - val_y2_output_root_mean_squared_error: 0.7458
# Epoch 465/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4178 - y1_output_loss: 0.1196 - y2_output_loss: 0.2982 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5458 - val_loss: 1.7685 - val_y1_output_loss: 0.4260 - val_y2_output_loss: 1.4206 - val_y1_output_root_mean_squared_error: 0.6543 - val_y2_output_root_mean_squared_error: 1.1578
# Epoch 466/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4211 - y1_output_loss: 0.1426 - y2_output_loss: 0.2856 - y1_output_root_mean_squared_error: 0.3740 - y2_output_root_mean_squared_error: 0.5303 - val_loss: 0.9214 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 0.6923 - val_y1_output_root_mean_squared_error: 0.4578 - val_y2_output_root_mean_squared_error: 0.8437
# Epoch 467/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3735 - y1_output_loss: 0.1193 - y2_output_loss: 0.2672 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.5065 - val_loss: 1.9796 - val_y1_output_loss: 0.6872 - val_y2_output_loss: 1.4111 - val_y1_output_root_mean_squared_error: 0.7580 - val_y2_output_root_mean_squared_error: 1.1853
# Epoch 468/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4347 - y1_output_loss: 0.1383 - y2_output_loss: 0.2926 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5435 - val_loss: 0.7578 - val_y1_output_loss: 0.2650 - val_y2_output_loss: 0.5273 - val_y1_output_root_mean_squared_error: 0.4665 - val_y2_output_root_mean_squared_error: 0.7349
# Epoch 469/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3105 - y1_output_loss: 0.0953 - y2_output_loss: 0.2145 - y1_output_root_mean_squared_error: 0.3100 - y2_output_root_mean_squared_error: 0.4630 - val_loss: 0.7902 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.5804 - val_y1_output_root_mean_squared_error: 0.4545 - val_y2_output_root_mean_squared_error: 0.7639
# Epoch 470/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3246 - y1_output_loss: 0.1003 - y2_output_loss: 0.2230 - y1_output_root_mean_squared_error: 0.3169 - y2_output_root_mean_squared_error: 0.4734 - val_loss: 0.7432 - val_y1_output_loss: 0.2309 - val_y2_output_loss: 0.5285 - val_y1_output_root_mean_squared_error: 0.4535 - val_y2_output_root_mean_squared_error: 0.7331
# Epoch 471/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2783 - y1_output_loss: 0.1144 - y2_output_loss: 0.1763 - y1_output_root_mean_squared_error: 0.3289 - y2_output_root_mean_squared_error: 0.4124 - val_loss: 1.5880 - val_y1_output_loss: 0.5688 - val_y2_output_loss: 1.1157 - val_y1_output_root_mean_squared_error: 0.6965 - val_y2_output_root_mean_squared_error: 1.0502
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5130 - y1_output_loss: 0.1731 - y2_output_loss: 0.3353 - y1_output_root_mean_squared_error: 0.4178 - y2_output_root_mean_squared_error: 0.5818 - val_loss: 0.7291 - val_y1_output_loss: 0.1654 - val_y2_output_loss: 0.5746 - val_y1_output_root_mean_squared_error: 0.4025 - val_y2_output_root_mean_squared_error: 0.7531
# Epoch 473/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3048 - y1_output_loss: 0.0977 - y2_output_loss: 0.2054 - y1_output_root_mean_squared_error: 0.3129 - y2_output_root_mean_squared_error: 0.4549 - val_loss: 0.8646 - val_y1_output_loss: 0.1925 - val_y2_output_loss: 0.6967 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 0.8218
# Epoch 474/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3326 - y1_output_loss: 0.1182 - y2_output_loss: 0.2120 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4620 - val_loss: 0.6981 - val_y1_output_loss: 0.2051 - val_y2_output_loss: 0.4997 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 0.7140
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3235 - y1_output_loss: 0.1125 - y2_output_loss: 0.2146 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4598 - val_loss: 2.0097 - val_y1_output_loss: 0.4217 - val_y2_output_loss: 1.6549 - val_y1_output_root_mean_squared_error: 0.6396 - val_y2_output_root_mean_squared_error: 1.2651
# Epoch 476/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3945 - y1_output_loss: 0.1115 - y2_output_loss: 0.2811 - y1_output_root_mean_squared_error: 0.3337 - y2_output_root_mean_squared_error: 0.5321 - val_loss: 0.8822 - val_y1_output_loss: 0.3176 - val_y2_output_loss: 0.5975 - val_y1_output_root_mean_squared_error: 0.5207 - val_y2_output_root_mean_squared_error: 0.7817
# Epoch 477/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3419 - y1_output_loss: 0.1226 - y2_output_loss: 0.2183 - y1_output_root_mean_squared_error: 0.3496 - y2_output_root_mean_squared_error: 0.4687 - val_loss: 0.9592 - val_y1_output_loss: 0.4154 - val_y2_output_loss: 0.5751 - val_y1_output_root_mean_squared_error: 0.6054 - val_y2_output_root_mean_squared_error: 0.7699
# Epoch 478/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3658 - y1_output_loss: 0.1266 - y2_output_loss: 0.2392 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 0.6767 - val_y1_output_loss: 0.1823 - val_y2_output_loss: 0.5010 - val_y1_output_root_mean_squared_error: 0.4138 - val_y2_output_root_mean_squared_error: 0.7110
# Epoch 479/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3345 - y1_output_loss: 0.1116 - y2_output_loss: 0.2207 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.4716 - val_loss: 0.6675 - val_y1_output_loss: 0.1842 - val_y2_output_loss: 0.4868 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.7019
# Epoch 480/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6500 - y1_output_loss: 0.2270 - y2_output_loss: 0.4189 - y1_output_root_mean_squared_error: 0.4772 - y2_output_root_mean_squared_error: 0.6499 - val_loss: 1.0266 - val_y1_output_loss: 0.2894 - val_y2_output_loss: 0.7692 - val_y1_output_root_mean_squared_error: 0.5027 - val_y2_output_root_mean_squared_error: 0.8797
# Epoch 481/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3203 - y1_output_loss: 0.1076 - y2_output_loss: 0.2107 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4605 - val_loss: 0.9224 - val_y1_output_loss: 0.1767 - val_y2_output_loss: 0.7751 - val_y1_output_root_mean_squared_error: 0.4106 - val_y2_output_root_mean_squared_error: 0.8682
# Epoch 482/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3715 - y1_output_loss: 0.1200 - y2_output_loss: 0.2498 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.5022 - val_loss: 0.6741 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.5031 - val_y1_output_root_mean_squared_error: 0.4063 - val_y2_output_root_mean_squared_error: 0.7134
# Epoch 483/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4706 - y1_output_loss: 0.1231 - y2_output_loss: 0.3480 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.5894 - val_loss: 1.1426 - val_y1_output_loss: 0.2250 - val_y2_output_loss: 0.9285 - val_y1_output_root_mean_squared_error: 0.4701 - val_y2_output_root_mean_squared_error: 0.9600
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4308 - y1_output_loss: 0.1288 - y2_output_loss: 0.3020 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5503 - val_loss: 0.7468 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.5787 - val_y1_output_root_mean_squared_error: 0.4125 - val_y2_output_root_mean_squared_error: 0.7594
# Epoch 485/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.2954 - y1_output_loss: 0.1295 - y2_output_loss: 0.1780 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.4163 - val_loss: 3.9762 - val_y1_output_loss: 2.1026 - val_y2_output_loss: 2.5801 - val_y1_output_root_mean_squared_error: 1.2682 - val_y2_output_root_mean_squared_error: 1.5388
# Epoch 486/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.8153 - y1_output_loss: 0.3207 - y2_output_loss: 0.4891 - y1_output_root_mean_squared_error: 0.5679 - y2_output_root_mean_squared_error: 0.7020 - val_loss: 0.7490 - val_y1_output_loss: 0.2069 - val_y2_output_loss: 0.5333 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.7431
# Epoch 487/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3961 - y1_output_loss: 0.1329 - y2_output_loss: 0.2609 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.5120 - val_loss: 0.7413 - val_y1_output_loss: 0.2467 - val_y2_output_loss: 0.5165 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 0.7272
# Epoch 488/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3406 - y1_output_loss: 0.1020 - y2_output_loss: 0.2369 - y1_output_root_mean_squared_error: 0.3197 - y2_output_root_mean_squared_error: 0.4882 - val_loss: 0.7120 - val_y1_output_loss: 0.1732 - val_y2_output_loss: 0.5479 - val_y1_output_root_mean_squared_error: 0.4068 - val_y2_output_root_mean_squared_error: 0.7393
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3025 - y1_output_loss: 0.1008 - y2_output_loss: 0.2041 - y1_output_root_mean_squared_error: 0.3160 - y2_output_root_mean_squared_error: 0.4502 - val_loss: 1.1405 - val_y1_output_loss: 0.3105 - val_y2_output_loss: 0.8682 - val_y1_output_root_mean_squared_error: 0.5504 - val_y2_output_root_mean_squared_error: 0.9152
# Epoch 490/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3279 - y1_output_loss: 0.1065 - y2_output_loss: 0.2208 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4703 - val_loss: 0.9501 - val_y1_output_loss: 0.3856 - val_y2_output_loss: 0.6283 - val_y1_output_root_mean_squared_error: 0.5558 - val_y2_output_root_mean_squared_error: 0.8007
# Epoch 491/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3295 - y1_output_loss: 0.1085 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4704 - val_loss: 0.6278 - val_y1_output_loss: 0.1535 - val_y2_output_loss: 0.4836 - val_y1_output_root_mean_squared_error: 0.3883 - val_y2_output_root_mean_squared_error: 0.6907
# Epoch 492/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3196 - y1_output_loss: 0.1048 - y2_output_loss: 0.2134 - y1_output_root_mean_squared_error: 0.3245 - y2_output_root_mean_squared_error: 0.4629 - val_loss: 0.6574 - val_y1_output_loss: 0.1953 - val_y2_output_loss: 0.4733 - val_y1_output_root_mean_squared_error: 0.4266 - val_y2_output_root_mean_squared_error: 0.6895
# Epoch 493/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.2852 - y1_output_loss: 0.1011 - y2_output_loss: 0.1828 - y1_output_root_mean_squared_error: 0.3189 - y2_output_root_mean_squared_error: 0.4283 - val_loss: 0.7218 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.5262 - val_y1_output_root_mean_squared_error: 0.4290 - val_y2_output_root_mean_squared_error: 0.7333
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2872 - y1_output_loss: 0.1092 - y2_output_loss: 0.1772 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.4219 - val_loss: 0.6629 - val_y1_output_loss: 0.2050 - val_y2_output_loss: 0.4641 - val_y1_output_root_mean_squared_error: 0.4307 - val_y2_output_root_mean_squared_error: 0.6909
# Epoch 495/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.2938 - y1_output_loss: 0.1022 - y2_output_loss: 0.1897 - y1_output_root_mean_squared_error: 0.3209 - y2_output_root_mean_squared_error: 0.4368 - val_loss: 0.6394 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.4704 - val_y1_output_root_mean_squared_error: 0.3982 - val_y2_output_root_mean_squared_error: 0.6935
# Epoch 496/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2740 - y1_output_loss: 0.1011 - y2_output_loss: 0.1722 - y1_output_root_mean_squared_error: 0.3177 - y2_output_root_mean_squared_error: 0.4160 - val_loss: 0.8869 - val_y1_output_loss: 0.2092 - val_y2_output_loss: 0.6994 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.8307
# Epoch 497/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4373 - y1_output_loss: 0.1374 - y2_output_loss: 0.2964 - y1_output_root_mean_squared_error: 0.3722 - y2_output_root_mean_squared_error: 0.5466 - val_loss: 0.7207 - val_y1_output_loss: 0.2162 - val_y2_output_loss: 0.5155 - val_y1_output_root_mean_squared_error: 0.4410 - val_y2_output_root_mean_squared_error: 0.7253
# Epoch 498/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3770 - y1_output_loss: 0.1249 - y2_output_loss: 0.2505 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 0.7316 - val_y1_output_loss: 0.2397 - val_y2_output_loss: 0.5040 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.7194
# Epoch 499/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3517 - y1_output_loss: 0.1229 - y2_output_loss: 0.2312 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 1.4738 - val_y1_output_loss: 0.2857 - val_y2_output_loss: 1.2290 - val_y1_output_root_mean_squared_error: 0.5356 - val_y2_output_root_mean_squared_error: 1.0894
# Epoch 500/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3586 - y1_output_loss: 0.1196 - y2_output_loss: 0.2387 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 0.7402 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.5390 - val_y1_output_root_mean_squared_error: 0.4399 - val_y2_output_root_mean_squared_error: 0.7394

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.7402 - y1_output_loss: 0.1989 - y2_output_loss: 0.5479 - y1_output_root_mean_squared_error: 0.4399 - y2_output_root_mean_squared_error: 0.7394
# Loss = 0.7401677749373696, Y1_loss = 0.19894108176231384, Y1_mse = 0.4398726522922516, Y2_loss = 0.5478533506393433, Y2_mse = 0.739378035068512

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
